# %% [markdown]
# # MIBiG JSON -> SMILES

# %% [markdown]
# Load MIBiG database in JSON format and extract the predicted SMILES (either already stored in the json file or retrieved from PubChem).

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import os
from glob import glob
import json

from pubchempy import *

# %%
input_dir = 'mibig_json_1.4/'

# %%
def get_isomeric_smiles(prop):
    for prop in pubchem_compound.record['props']:
        urn = prop['urn']
        if 'name' in urn and urn['name'] == 'Isomeric' and urn['label'] == 'SMILES':
            smiles = prop['value']['sval']
            return smiles

# %% [markdown]
# Sometimes the MIBiG json doesn't contain the chemical structure (SMILES), but it has the pubchem id. In this case, we can fetch this information from pubchem.

# %%
data = []
json_files = glob(os.path.join(input_dir, '*.json'))
for fn in sorted(json_files):
    with open(fn, 'r') as f:
        
        d = json.load(f)    
        
        bgc_id = os.path.basename(fn).split('.')[0]
        compounds = d['general_params']['compounds']
        for c in compounds:
            compound_name = bgc_id + '_' + c['compound'].lower().replace(' ', '_')
            if 'chem_struct' in c:
                smiles = c['chem_struct']
            elif 'pubchem_id' in c:
                try:
                    pubchem_id = c['pubchem_id']
                    pubchem_compound = Compound.from_cid(pubchem_id)
                    props = pubchem_compound.record['props']
                    smiles = get_isomeric_smiles(props)
                except NotFoundError:
                    smiles = None
                    
            if smiles is not None:
                row = (compound_name, smiles,)
#                 print row
                data.append(row)
                if len(data) % 100 == 0:
                    print(len(data), '/', len(json_files))
# Out:
# ['mibig_json_1.4\\BGC0000001.json', 'mibig_json_1.4\\BGC0000002.json', 'mibig_json_1.4\\BGC0000003.json', 'mibig_json_1.4\\BGC0000004.json', 'mibig_json_1.4\\BGC0000005.json', 'mibig_json_1.4\\BGC0000006.json', 'mibig_json_1.4\\BGC0000007.json', 'mibig_json_1.4\\BGC0000008.json', 'mibig_json_1.4\\BGC0000009.json', 'mibig_json_1.4\\BGC0000010.json', 'mibig_json_1.4\\BGC0000011.json', 'mibig_json_1.4\\BGC0000012.json', 'mibig_json_1.4\\BGC0000013.json', 'mibig_json_1.4\\BGC0000014.json', 'mibig_json_1.4\\BGC0000015.json', 'mibig_json_1.4\\BGC0000016.json', 'mibig_json_1.4\\BGC0000017.json', 'mibig_json_1.4\\BGC0000018.json', 'mibig_json_1.4\\BGC0000019.json', 'mibig_json_1.4\\BGC0000020.json', 'mibig_json_1.4\\BGC0000021.json', 'mibig_json_1.4\\BGC0000022.json', 'mibig_json_1.4\\BGC0000023.json', 'mibig_json_1.4\\BGC0000024.json', 'mibig_json_1.4\\BGC0000025.json', 'mibig_json_1.4\\BGC0000026.json', 'mibig_json_1.4\\BGC0000027.json', 'mibig_json_1.4\\BGC0000028.json', 'mibig_json_1.4\\BGC0000029.json', 'mibig_json_1.4\\BGC0000030.json', 'mibig_json_1.4\\BGC0000031.json', 'mibig_json_1.4\\BGC0000032.json', 'mibig_json_1.4\\BGC0000033.json', 'mibig_json_1.4\\BGC0000034.json', 'mibig_json_1.4\\BGC0000035.json', 'mibig_json_1.4\\BGC0000036.json', 'mibig_json_1.4\\BGC0000037.json', 'mibig_json_1.4\\BGC0000038.json', 'mibig_json_1.4\\BGC0000039.json', 'mibig_json_1.4\\BGC0000040.json', 'mibig_json_1.4\\BGC0000041.json', 'mibig_json_1.4\\BGC0000042.json', 'mibig_json_1.4\\BGC0000043.json', 'mibig_json_1.4\\BGC0000044.json', 'mibig_json_1.4\\BGC0000045.json', 'mibig_json_1.4\\BGC0000046.json', 'mibig_json_1.4\\BGC0000047.json', 'mibig_json_1.4\\BGC0000048.json', 'mibig_json_1.4\\BGC0000049.json', 'mibig_json_1.4\\BGC0000050.json', 'mibig_json_1.4\\BGC0000051.json', 'mibig_json_1.4\\BGC0000052.json', 'mibig_json_1.4\\BGC0000053.json', 'mibig_json_1.4\\BGC0000054.json', 'mibig_json_1.4\\BGC0000055.json', 'mibig_json_1.4\\BGC0000056.json', 'mibig_json_1.4\\BGC0000057.json', 'mibig_json_1.4\\BGC0000058.json', 'mibig_json_1.4\\BGC0000059.json', 'mibig_json_1.4\\BGC0000060.json', 'mibig_json_1.4\\BGC0000061.json', 'mibig_json_1.4\\BGC0000062.json', 'mibig_json_1.4\\BGC0000063.json', 'mibig_json_1.4\\BGC0000064.json', 'mibig_json_1.4\\BGC0000065.json', 'mibig_json_1.4\\BGC0000066.json', 'mibig_json_1.4\\BGC0000067.json', 'mibig_json_1.4\\BGC0000068.json', 'mibig_json_1.4\\BGC0000069.json', 'mibig_json_1.4\\BGC0000070.json', 'mibig_json_1.4\\BGC0000072.json', 'mibig_json_1.4\\BGC0000073.json', 'mibig_json_1.4\\BGC0000074.json', 'mibig_json_1.4\\BGC0000075.json', 'mibig_json_1.4\\BGC0000076.json', 'mibig_json_1.4\\BGC0000077.json', 'mibig_json_1.4\\BGC0000078.json', 'mibig_json_1.4\\BGC0000079.json', 'mibig_json_1.4\\BGC0000080.json', 'mibig_json_1.4\\BGC0000081.json', 'mibig_json_1.4\\BGC0000082.json', 'mibig_json_1.4\\BGC0000083.json', 'mibig_json_1.4\\BGC0000084.json', 'mibig_json_1.4\\BGC0000085.json', 'mibig_json_1.4\\BGC0000086.json', 'mibig_json_1.4\\BGC0000087.json', 'mibig_json_1.4\\BGC0000088.json', 'mibig_json_1.4\\BGC0000089.json', 'mibig_json_1.4\\BGC0000090.json', 'mibig_json_1.4\\BGC0000091.json', 'mibig_json_1.4\\BGC0000092.json', 'mibig_json_1.4\\BGC0000093.json', 'mibig_json_1.4\\BGC0000094.json', 'mibig_json_1.4\\BGC0000095.json', 'mibig_json_1.4\\BGC0000096.json', 'mibig_json_1.4\\BGC0000097.json', 'mibig_json_1.4\\BGC0000098.json', 'mibig_json_1.4\\BGC0000099.json', 'mibig_json_1.4\\BGC0000100.json', 'mibig_json_1.4\\BGC0000101.json', 'mibig_json_1.4\\BGC0000102.json', 'mibig_json_1.4\\BGC0000103.json', 'mibig_json_1.4\\BGC0000104.json', 'mibig_json_1.4\\BGC0000105.json', 'mibig_json_1.4\\BGC0000106.json', 'mibig_json_1.4\\BGC0000107.json', 'mibig_json_1.4\\BGC0000108.json', 'mibig_json_1.4\\BGC0000109.json', 'mibig_json_1.4\\BGC0000110.json', 'mibig_json_1.4\\BGC0000111.json', 'mibig_json_1.4\\BGC0000112.json', 'mibig_json_1.4\\BGC0000113.json', 'mibig_json_1.4\\BGC0000114.json', 'mibig_json_1.4\\BGC0000115.json', 'mibig_js ...
# 100 / 1816
# 200 / 1816
# 300 / 1816
# 400 / 1816
# 500 / 1816
# 600 / 1816
# 700 / 1816
# 800 / 1816
# 900 / 1816
# 1000 / 1816
# 1100 / 1816
# 1200 / 1816
# 1300 / 1816
# 1400 / 1816
# 1500 / 1816
# 1600 / 1816
# 1700 / 1816
# 1800 / 1816
# 1900 / 1816
# 2000 / 1816
# 2100 / 1816
# 2200 / 1816
# 2300 / 1816
# 2400 / 1816

# %% [markdown]
# Export the results to csv

# %%
import pandas as pd
df = pd.DataFrame(data, columns=['mol', 'smiles'])
df.to_csv('smiles.tsv', sep='\t', header=None, index=False)
